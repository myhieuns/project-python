# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('Downloads\data.xlsx')

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.count()
#dem so luong dong
# Out:
# InvoiceNo      541909
# StockCode      541909
# Description    540455
# Quantity       541909
# InvoiceDate    541909
# UnitPrice      541909
# CustomerID     406829
# Country        541909
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
import datetime

# %%
current_date = max(df['InvoiceDate'] + datetime.timedelta(days = 1))

# %%
current_date
# Out:
# Timestamp('2011-12-10 12:50:00')

# %%
df['TotalPay'] = df['Quantity'] * df['UnitPrice']

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalPay
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom     15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom     22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom     20.34

# %%
df['Quantity'].describe()
# Out:
# count    541909.000000
# mean          9.552250
# std         218.081158
# min      -80995.000000
# 25%           1.000000
# 50%           3.000000
# 75%          10.000000
# max       80995.000000
# Name: Quantity, dtype: float64

# %%
df['UnitPrice'].describe()
# Out:
# count    541909.000000
# mean          4.611114
# std          96.759853
# min      -11062.060000
# 25%           1.250000
# 50%           2.080000
# 75%           4.130000
# max       38970.000000
# Name: UnitPrice, dtype: float64

# %%
indexrows = df[df['UnitPrice'] < 0].index
df.drop(indexrows)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPay
# ...

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPay
# ...

# %%
df[df['Quantity'] < 0]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPay
# ...

# %%
df['UnitPrice'].apply(lambda x: x == 0).value_counts()
# Out:
# False    539394
# True       2515
# Name: UnitPrice, dtype: int64

# %%
df.loc[df['StockCode'] ==  'B', 'UnitPrice'] = 11062.06

# %%
df.loc[df['StockCode'] == 'B']
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299982   A563185         B  Adjust bad debt         1 2011-08-12 14:50:00
# 299983   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country  TotalPay
# 299982   11062.06         NaN  United Kingdom  11062.06
# 299983   11062.06         NaN  United Kingdom  11062.06
# 299984   11062.06         NaN  United Kingdom  11062.06

# %%
df[df['UnitPrice'] == 0].value_counts(df['StockCode'])
# Out:
# StockCode
# 23084           16
# 35965           13
# 20713           11
# 22501           10
# 22627            9
#                 ..
# 22667            1
# 22690            1
# 22696            1
# 22699            1
# gift_0001_30     1
# Length: 1419, dtype: int64

# %%
df.drop("Description", axis = 1, inplace = True)

# %%
df[df['StockCode'] == 23084].value_counts("UnitPrice")
# Out:
# UnitPrice
# 2.08    610
# 1.79    259
# 4.13    163
# 0.00     16
# 4.96     16
# 4.95      2
# 1.67      1
# dtype: int64

# %%
df
# Out:
#        InvoiceNo StockCode  Quantity         InvoiceDate  UnitPrice  \
# 0         536365    85123A         6 2010-12-01 08:26:00       2.55
# 1         536365     71053         6 2010-12-01 08:26:00       3.39
# 2         536365    84406B         8 2010-12-01 08:26:00       2.75
# 3         536365    84029G         6 2010-12-01 08:26:00       3.39
# 4         536365    84029E         6 2010-12-01 08:26:00       3.39
# ...          ...       ...       ...                 ...        ...
# 541904    581587     22613        12 2011-12-09 12:50:00       0.85
# 541905    581587     22899         6 2011-12-09 12:50:00       2.10
# 541906    581587     23254         4 2011-12-09 12:50:00       4.15
# 541907    581587     23255         4 2011-12-09 12:50:00       4.15
# 541908    581587     22138         3 2011-12-09 12:50:00       4.95
#
#         CustomerID         Country  TotalPay
# 0          17850.0  United Kingdom     15.30
# 1          17850.0  United Kingdom     20.34
# ...

# %%
df1 = df.copy()

# %%
# Out:
#        InvoiceNo StockCode  Quantity         InvoiceDate  UnitPrice  \
# 0         536365    85123A         6 2010-12-01 08:26:00       2.55
# 1         536365     71053         6 2010-12-01 08:26:00       3.39
# 2         536365    84406B         8 2010-12-01 08:26:00       2.75
# 3         536365    84029G         6 2010-12-01 08:26:00       3.39
# 4         536365    84029E         6 2010-12-01 08:26:00       3.39
# ...          ...       ...       ...                 ...        ...
# 541904    581587     22613        12 2011-12-09 12:50:00       0.85
# 541905    581587     22899         6 2011-12-09 12:50:00       2.10
# 541906    581587     23254         4 2011-12-09 12:50:00       4.15
# 541907    581587     23255         4 2011-12-09 12:50:00       4.15
# 541908    581587     22138         3 2011-12-09 12:50:00       4.95
#
#         CustomerID         Country  TotalPay
# 0          17850.0  United Kingdom     15.30
# 1          17850.0  United Kingdom     20.34
# ...

# %%
df['Quantity'].describe()
# Out:
# count    541909.000000
# mean          9.552250
# std         218.081158
# min      -80995.000000
# 25%           1.000000
# 50%           3.000000
# 75%          10.000000
# max       80995.000000
# Name: Quantity, dtype: float64

# %%
df.corr()
# Out:
#             Quantity  UnitPrice  CustomerID  TotalPay
# Quantity    1.000000  -0.001268   -0.003600  0.886682
# UnitPrice  -0.001268   1.000000   -0.004560 -0.162087
# CustomerID -0.003600  -0.004560    1.000000 -0.002274
# TotalPay    0.886682  -0.162087   -0.002274  1.000000

# %%
sns.boxplot(df['UnitPrice'])
# Out:
# <AxesSubplot:>

# %%
sns.distplot(df['UnitPrice'])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5872\2450390939.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['UnitPrice'])
# <AxesSubplot:xlabel='UnitPrice', ylabel='Density'>

# %%
df_customers = df.groupby('CustomerID').agg({
    'InvoiceDate': lambda x: (current_date - x.max()).days,
    'InvoiceNo': 'count',
    'TotalPay': 'sum'
})

# %%
df_customers
# Out:
#             InvoiceDate  InvoiceNo  TotalPay
# CustomerID
# 12346.0             326          2      0.00
# 12347.0               2        182   4310.00
# 12348.0              75         31   1797.24
# 12349.0              19         73   1757.55
# 12350.0             310         17    334.40
# ...                 ...        ...       ...
# 18280.0             278         10    180.60
# 18281.0             181          7     80.82
# 18282.0               8         13    176.60
# 18283.0               4        756   2094.88
# 18287.0              43         70   1837.28
#
# [4372 rows x 3 columns]

# %%
df_customers.rename(columns= {
    'InvoiceDate': 'Recency',
    'InvoiceNo': 'Frequency',
    'TotalPay': 'Monetary'
}, inplace = True)

# %%
fig, ax = plt.subplots(3,1, figsize = (15,10))
sns.distplot(df_customers['Recency'], ax = ax[0])
sns.distplot(df_customers['Frequency'], ax = ax[1])
sns.distplot(df_customers['Monetary'], ax = ax[2])
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5872\2428310630.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_customers['Recency'], ax = ax[0])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5872\2428310630.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
df_customers
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12346.0         326          2      0.00
# 12347.0           2        182   4310.00
# 12348.0          75         31   1797.24
# 12349.0          19         73   1757.55
# 12350.0         310         17    334.40
# ...             ...        ...       ...
# 18280.0         278         10    180.60
# 18281.0         181          7     80.82
# 18282.0           8         13    176.60
# 18283.0           4        756   2094.88
# 18287.0          43         70   1837.28
#
# [4372 rows x 3 columns]

# %%
# !pip install scipy

# %%
from scipy import stats
import numpy as np

# %%
def analyze_skewness(x):
    fig, ax = plt.subplots(2,2,figsize = (8,8))
    sns.distplot(df_customers[x], ax = ax[0,0])
    sns.distplot(np.log(df_customers[x]), ax = ax[0,1])
    sns.distplot(np.sqrt(df_customers[x]), ax = ax[1,0])
    sns.distplot(stats.boxcox(df_customers[x])[0], ax = ax[1,1])
    plt.tight_layout()
    plt.show()
    
    print(df_customers[x].skew().round(2))
    print(np.log(df_customers[x]).skew().round(2))
    print(np.sqrt(df_customers[x]).skew().round(2))
    print(pd.Series(stats.boxcox(df_customers[x])[0]).skew().round(2))

# %%
analyze_skewness('Recency')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5872\1207154225.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_customers[x], ax = ax[0,0])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5872\1207154225.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
analyze_skewness('Frequency')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5872\1207154225.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_customers[x], ax = ax[0,0])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5872\1207154225.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
df1 = df_customers.copy()

# %%
df1
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12346.0         326          2      0.00
# 12347.0           2        182   4310.00
# 12348.0          75         31   1797.24
# 12349.0          19         73   1757.55
# 12350.0         310         17    334.40
# ...             ...        ...       ...
# 18280.0         278         10    180.60
# 18281.0         181          7     80.82
# 18282.0           8         13    176.60
# 18283.0           4        756   2094.88
# 18287.0          43         70   1837.28
#
# [4372 rows x 3 columns]

# %%
df_customers
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12346.0         326          2      0.00
# 12347.0           2        182   4310.00
# 12348.0          75         31   1797.24
# 12349.0          19         73   1757.55
# 12350.0         310         17    334.40
# ...             ...        ...       ...
# 18280.0         278         10    180.60
# 18281.0         181          7     80.82
# 18282.0           8         13    176.60
# 18283.0           4        756   2094.88
# 18287.0          43         70   1837.28
#
# [4372 rows x 3 columns]

# %%
df1['Recency'] = stats.boxcox(df1['Recency'])[0]
df1['Frequency'] = stats.boxcox(df1['Frequency'])[0]
df1['Monetary'] = np.cbrt(df1['Monetary'])

# %%
df1
# Out:
#              Recency  Frequency   Monetary
# CustomerID
# 12346.0     9.876619   0.707055   0.000000
# 12347.0     0.735846   6.060363  16.273929
# 12348.0     6.384920   3.794006  12.158183
# 12349.0     3.826255   4.862047  12.068017
# 12350.0     9.741979   3.075409   6.941001
# ...              ...        ...        ...
# 18280.0     9.454427   2.460908   5.652483
# 18281.0     8.372488   2.058202   4.323541
# 18282.0     2.496606   2.762414   5.610440
# 18283.0     1.564173   8.057611  12.795376
# 18287.0     5.275521   4.808490  12.247810
#
# [4372 rows x 3 columns]

# %%
# !pip install sklearn
# Out:
# ...
#   Using cached sklearn-0.0.post1.tar.gz (3.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Running setup.py install for sklearn: started
#   Running setup.py install for sklearn: finished with status 'done'
# ...
#   DEPRECATION: sklearn is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(df1)
df1 = scaler.transform(df1)
pd.DataFrame(df1)
# Out:
#              0         1         2
# 0     1.611173 -2.098072 -1.925647
# 1    -1.797592  1.151346  1.330542
# 2     0.309053 -0.224316  0.507038
# 3    -0.645121  0.423978  0.488997
# 4     1.560964 -0.660498 -0.536848
# ...        ...       ...       ...
# 4367  1.453730 -1.033496 -0.794663
# 4368  1.050255 -1.277936 -1.060566
# 4369 -1.140972 -0.850484 -0.803075
# 4370 -1.488693  2.363661  0.634531
# 4371 -0.104662  0.391469  0.524971
#
# [4372 rows x 3 columns]

# %%
from sklearn.cluster import KMeans

# %%
sse = {}
for k in range(1,11):
    kmeans = KMeans(n_clusters= k, random_state = 42)
    kmeans.fit(df1)
    sse[k] = kmeans.inertia_
sns.pointplot(x = list(sse.keys()), y = list(sse.values()))
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[191], line 1
# ----> 1 Elbow_M = KElbowVisualizer(KMeans(), k=10)
#       2 Elbow_M.fit(df1)
#       3 Elbow_M.show()
#
# NameError: name 'KElbowVisualizer' is not defined

# %%
from yellowbrick.cluster import KElbowVisualizer

# %%
# !pip install yellowbrick
# Out:
# ...
#      ---------------------------------------- 0.0/282.6 kB ? eta -:--:--
#      ---- ----------------------------------- 30.7/282.6 kB ? eta -:--:--
#      ------------ -------------------------- 92.2/282.6 kB 1.3 MB/s eta 0:00:01
#      ---------------- --------------------- 122.9/282.6 kB 1.2 MB/s eta 0:00:01
#      ---------------- --------------------- 122.9/282.6 kB 1.2 MB/s eta 0:00:01
#      ---------------- --------------------- 122.9/282.6 kB 1.2 MB/s eta 0:00:01
#      ---------------------------------- --- 256.0/282.6 kB 1.1 MB/s eta 0:00:01
#      ------------------------------------ 282.6/282.6 kB 969.3 kB/s eta 0:00:00
# ...

# %%
Elbow_M = KElbowVisualizer(KMeans(), k=10)
Elbow_M.fit(df1)
Elbow_M.show()
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
df1
# Out:
# array([[ 1.61117306, -2.09807168, -1.92564704],
#        [-1.79759219,  1.15134635,  1.33054192],
#        [ 0.30905346, -0.22431569,  0.50703791],
#        ...,
#        [-1.14097185, -0.85048403, -0.80307538],
#        [-1.48869338,  2.36366091,  0.63453134],
#        [-0.10466245,  0.391469  ,  0.52497099]])

# %%
model = KMeans(n_clusters = 3, random_state = 42)
model.fit(df1)
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=3, random_state=42)

# %%
df_customers
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12346.0         326          2      0.00
# 12347.0           2        182   4310.00
# 12348.0          75         31   1797.24
# 12349.0          19         73   1757.55
# 12350.0         310         17    334.40
# ...             ...        ...       ...
# 18280.0         278         10    180.60
# 18281.0         181          7     80.82
# 18282.0           8         13    176.60
# 18283.0           4        756   2094.88
# 18287.0          43         70   1837.28
#
# [4372 rows x 3 columns]

# %%
df_customers['Cluster'] = model.labels_

# %%
df_customers
# Out:
#             Recency  Frequency  Monetary  Cluster
# CustomerID
# 12346.0         326          2      0.00        1
# 12347.0           2        182   4310.00        0
# 12348.0          75         31   1797.24        2
# 12349.0          19         73   1757.55        2
# 12350.0         310         17    334.40        1
# ...             ...        ...       ...      ...
# 18280.0         278         10    180.60        1
# 18281.0         181          7     80.82        1
# 18282.0           8         13    176.60        2
# 18283.0           4        756   2094.88        0
# 18287.0          43         70   1837.28        2
#
# [4372 rows x 4 columns]

# %%
df_customer_cluster = df_customers.copy()

# %%
df_customers.groupby('Cluster').agg(
    {
        'Recency' : 'mean',
        'Frequency': 'mean',
        'Monetary': 'mean'
    
    }
)
# Out:
#             Recency   Frequency     Monetary
# Cluster
# 0         17.877707  312.264968  7356.522790
# 1        185.513956   19.145024   351.297780
# 2         42.634863   67.122228  1003.742487

# %%
pd.value_counts(df_customers['Cluster'])
# Out:
# 2    1939
# 1    1648
# 0     785
# Name: Cluster, dtype: int64

# %%
df_customers['Cluster'].value_counts()
# Out:
# 2    1939
# 1    1648
# 0     785
# Name: Cluster, dtype: int64
